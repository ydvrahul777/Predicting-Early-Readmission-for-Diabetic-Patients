# %%
### Import  requried modules
import warnings
warnings.filterwarnings("ignore")
import sys, os
import pandas            as  pd
import numpy             as  np
import seaborn           as  sns
import matplotlib.pyplot as  plt
import statsmodels.api   as  sm
import time
from   datetime           import timedelta
from   sklearn.tree       import _tree
from   sklearn            import metrics
print("\nCurrent working directory %s" %os.getcwd())
# Out:
# Current working directory C:\Users\Rahul\OneDrive\Desktop\Projects\Predicting Early Readmission for Diabetic Patients

# %%
def spot_check_default_model_performance(n_splits, random_state, df, X, y):  

    ### To compare algorithms
    import  time
    import  matplotlib.pyplot           as       plt
    from    sklearn.model_selection     import   StratifiedKFold
    from    sklearn.model_selection     import   cross_val_score
    from    sklearn.linear_model        import   LogisticRegression
    from    sklearn.tree                import   DecisionTreeClassifier
    from    sklearn.neighbors           import   KNeighborsClassifier
    from    sklearn.naive_bayes         import   GaussianNB
    from    sklearn.ensemble            import   RandomForestClassifier
    from    sklearn.preprocessing       import   LabelEncoder
    from    xgboost                     import   XGBClassifier  
    from    sklearn.ensemble            import   AdaBoostClassifier
    from    sklearn.svm                 import   SVC   
    ### 
    cmp_default_model_start_time   =  time.time()
    
    models                         =  []
    models.append(('LR', LogisticRegression(max_iter = 10000)))
    models.append(('KNN', KNeighborsClassifier()))
    models.append(('CART', DecisionTreeClassifier()))
    models.append(('NB', GaussianNB()))
    models.append(('RF', RandomForestClassifier()))
    models.append(('XGBoost', XGBClassifier()))
    models.append(('AdaBoost', AdaBoostClassifier()))
    ###  models.append(('SVC', SVC(gamma='auto')))
                
    scores_req =  ['recall', 'roc_auc']   
       
    print("\n n_splits %d random_state %d" % (n_splits, random_state)) 
    df_recall     =   pd.DataFrame()   
    
    for i in range(len(scores_req)):
            results    =   []
            names      =   []        
            scoring    =  scores_req[i]
            
            print("\nMeasure: ", scoring, "Mean ± std.deviation, min, max")
            
            for name, model in models:
    
                skf             =   StratifiedKFold(n_splits = n_splits, random_state = random_state, shuffle = True)
                cv_results      =   cross_val_score(model, X, y, cv = skf, scoring = scoring)
                results.append(cv_results)	
                names.append(name)
                msg            =  "%s: %f ± %f %f %f" % (name, round(cv_results.mean(),2), round(cv_results.std(),2),round(cv_results.min(),2), round(cv_results.max(),2))     
                df_1           =   pd.DataFrame({'Model' : name, 'Recall': cv_results.mean()}, index = [0] )
                df_recall      =   pd.concat([df_recall, df_1], axis = 0) 
                print(msg)            
 
            ### Box plot algorithm comparison            
            sub_title = 'Algorithm Comparison using ' + scoring            
            fig = plt.figure()
            fig.suptitle(sub_title)
            ax  = fig.add_subplot(111)
            plt.boxplot(results)
            ax.set_xticklabels(names, rotation = 90)
            ax.axhline(y = 0.6, xmin = 0.0, xmax = 1.0, color = 'r')
            plt.show()
###
    cmp_default_model_end_time          =  time.time()
    time_taken                          =  cmp_default_model_end_time - cmp_default_model_start_time# time_taken is in seconds
    hours, rest                         =  divmod(time_taken,3600)
    minutes, seconds                    =  divmod(rest, 60)
    print("\nExecution time for comparison of models using default parameters: ", " Hours: ", hours, " Min: ", minutes, "Seconds: ", seconds)

# %%
def spot_check_model_performance(n_splits, random_state, df, X, y):  
    import  time
    ### To compare algorithms
    from    numpy                       import  nan
    import  matplotlib.pyplot           as       plt
    from    sklearn.model_selection     import   StratifiedKFold
    from    sklearn.model_selection     import   cross_val_score
    from    sklearn.linear_model        import   LogisticRegression
    from    sklearn.tree                import   DecisionTreeClassifier
    from    sklearn.neighbors           import   KNeighborsClassifier
    from    sklearn.naive_bayes         import   GaussianNB
    from    sklearn.ensemble            import   RandomForestClassifier
    from    sklearn.preprocessing       import   LabelEncoder
    from    xgboost                     import   XGBClassifier  
    from    sklearn.ensemble            import   AdaBoostClassifier
    from    sklearn.svm                 import   SVC   
    ### 
    cmp_tuned_model_start_time       =  time.time()    
    models                           = []

    models.append(('LR', LogisticRegression(warm_start = False, verbose =  0, tol =  0.001, solver =  'saga', random_state = None, \
                         penalty= 'l1', n_jobs = None, multi_class = 'auto', max_iter = 100, l1_ratio= None, intercept_scaling = 3, fit_intercept= True,\
                         dual = False, class_weight = None, C = 10000.0).fit(X,y)))
    models.append(('KNN', KNeighborsClassifier(weights = 'distance', p = 2, n_neighbors = 3, n_jobs = None, metric_params = None,\
                          metric = 'minkowski', leaf_size = 30, algorithm = 'auto').fit(X,y)))
    models.append(('CART', DecisionTreeClassifier(splitter = 'best', random_state =  None, min_weight_fraction_leaf =  0.0, min_samples_split =  2,\
                           min_samples_leaf =  10, min_impurity_decrease =  0.0,max_leaf_nodes =  None, max_features =  None, max_depth =  2,\
                           criterion = 'entropy', class_weight = 'balanced', ccp_alpha =  0.0).fit(X,y)))
    models.append(('NB', GaussianNB(var_smoothing = 1e-09).fit(X,y)))
    models.append(('RF', RandomForestClassifier(warm_start = False, verbose = 0, random_state = None,oob_score = False,n_jobs = None,n_estimators = 50,\
                         min_weight_fraction_leaf = 0.0,min_samples_split = 2, min_samples_leaf = 1,min_impurity_decrease = 0.0,max_samples = None,\
                         max_leaf_nodes = None,max_features = 0.75,max_depth = 5, criterion = 'gini', class_weight = 'balanced',ccp_alpha = 0.0,\
                         bootstrap = True).fit(X,y)))
    models.append(('XGBoost', XGBClassifier(verbosity = None, validate_parameters = None, tree_method = None, subsample = None, scale_pos_weight = None,\
                              sampling_method = None,reg_lambda = None,reg_alpha = None, random_state = None, objective = 'binary:logistic',\
                              num_parallel_tree = None, n_jobs = None, n_estimators = None, multi_strategy = None,\
                              monotone_constraints = None, missing = nan, min_child_weight = None, max_leaves = None, max_depth = 10,\
                              max_delta_step = None, max_cat_to_onehot = None, max_cat_threshold = None, max_bin = None, learning_rate = None,\
                              interaction_constraints = None, importance_type = None, grow_policy = None, gamma = None, feature_types = None,\
                              eval_metric = None,enable_categorical = False, early_stopping_rounds = None, device = None, colsample_bytree = None,\
                              colsample_bynode = None, colsample_bylevel = None, callbacks =  None, booster = None, base_score = None).fit(X,y)))
    models.append(('AdaBoost', AdaBoostClassifier(random_state = None, n_estimators = 10,learning_rate = 1,estimator = None,algorithm = 'SAMME.R').fit(X,y)))
                
    scores_req =  ['recall', 'roc_auc']   
    print("\nn_splits %d random_state %d" % (n_splits, random_state)) 
    df_recall     =   pd.DataFrame()   
    
    for i in range(len(scores_req)):
            results    =   []
            names      =   []        
            scoring    =  scores_req[i]
            print("\nMeasure: ", scoring, "Mean ± std.deviation, min, max")
            for name, model in models:
    
                skf             =   StratifiedKFold(n_splits = n_splits, random_state = random_state, shuffle = True)
                cv_results      =   cross_val_score(model, X, y, cv = skf, scoring = scoring)
                results.append(cv_results)	
                names.append(name)
                msg            =  "%s: %f ± %f %f %f" % (name, round(cv_results.mean(),2), round(cv_results.std(),2),round(cv_results.min(),2), round(cv_results.max(),2))     

                df_1           =   pd.DataFrame({'Model' : name, 'Measure' : scoring, 'Mean': cv_results.mean()}, index = [0] )
                df_recall      =   pd.concat([df_recall, df_1], axis = 0) 
                print(msg)           

 
            ### Box plot algorithm comparison            
            sub_title = 'Algorithm Comparison using ' + scoring            
            fig = plt.figure()
            fig.suptitle(sub_title)
            ax  = fig.add_subplot(111)
            plt.boxplot(results)
            ax.set_xticklabels(names, rotation = 90)
            ax.axhline(y = 0.6, xmin = 0.0, xmax = 1.0, color = 'r')
            plt.show()
    df_recall.sort_values(by = ['Measure', 'Mean'], ascending = False, inplace = True) 
###
    cmp_tuned_model_end_time            =  time.time()
    time_taken                          =  cmp_tuned_model_end_time - cmp_tuned_model_start_time# time_taken is in seconds
    hours, rest                         =  divmod(time_taken,3600)
    minutes, seconds                    =  divmod(rest, 60)
    print("\nExecution time for comparison of models using tuned parameters: ", " Hours: ", hours, " Min: ", minutes, "Seconds: ", seconds)

# %%
def  report_performance(clf, X_train,X_test,y_train,y_test):
        from    sklearn.metrics          import  recall_score, precision_score, f1_score
        import  matplotlib.pyplot        as      plt
        import  pandas                   as      pd
    
        print("\nUsing Training data\n")
        y_pred   =  clf.predict(X_train)
        print('precision score: %.2f' % precision_score(y_train,y_pred))
        print('recall score: %.2f' % recall_score(y_train,y_pred))
        print('f1 score: %.2f' % f1_score(y_train,y_pred))
        print("\nUsing Test data\n")
        y_pred   =  clf.predict(X_test)
        print('precision score: %.2f' % precision_score(y_test,y_pred))
        print('recall score: %.2f' % recall_score(y_test,y_pred))
        print('f1 score: %.2f' % f1_score(y_test,y_pred))

        # Get importance
        importance                                 =  clf.feature_importances_
        vars                                       =  X_train.columns
        varimp_df    =  pd.DataFrame({'Columns' : vars, '% Reduction in a criterion':importance})
        varimp_df['% Reduction in a criterion']    =  varimp_df['% Reduction in a criterion'] * 100
        varimp_df.sort_values(by = '% Reduction in a criterion', ascending = False, inplace = True)
        colsv        =  varimp_df['Columns'].tolist()
        print(varimp_df)
        plt.bar([x for x in colsv], varimp_df['% Reduction in a criterion'])
        plt.xticks(rotation=90)
        plt.show()

# %%
def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "
        if class_names is None:
            rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules

# %%
def draw_cm(mname, datacategory, actual, predicted ):
    
    import matplotlib.pyplot as   plt
    import sklearn.metrics   as   metrics
    import seaborn           as   sns
    print(metrics.classification_report(actual, predicted))
    cm = metrics.confusion_matrix( actual, predicted)
    sns.heatmap(cm, annot=True, fmt='.2f', xticklabels = ["Yes", "No"] , yticklabels = ["Yes", "No"] )
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    titlex =  'Confusion Matrix for the model: %s using %s ' % (mname, datacategory)    
    plt.title(titlex)
    plt.show()

# %%
def draw_roc(mname,datacategory, actual, probs ):
    import matplotlib.pyplot as   plt
    import sklearn.metrics   as   metrics
   
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
    drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 4))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    titlex =  'Receiver operating characteristic curve for the model:%s using %s ' % (mname, datacategory)   
    plt.title(titlex)
    plt.legend(loc="lower right")
    plt.show()
    return fpr, tpr, thresholds

# %%
def  draw_countplot(df, i, var, target):
     import  matplotlib.pyplot   as  plt
     import  seaborn             as  sns
     print("\n{0}: Variable, {1}".format(i, var))
     x         =  df[var]
     y         =  df[target]
     ttile     =  "Bar Chart for the variable: {}".format(var) 
     plt.title(ttile)    
     sns.countplot(x = x, hue = y, data = df)
     plt.xticks(rotation = 90)
     plt.show()

# %%
def  draw_boxplot(df, i, var, target):
     import  matplotlib.pyplot   as  plt
     import  seaborn             as  sns
     print("\n{0}: Variable, {1}".format(i, var))
     x         =  df[var]
     y         =  df[target]
     ttile     =  "Boxplot for the variable: {}".format(var) 
     plt.title(ttile)    
     sns.boxplot(x = x, hue = y, data = df)
     plt.xticks(rotation = 90)
     plt.show()

# %%
start_time = time.time()

# %%
import os

data_dir = r"C:\Users\Rahul\OneDrive\Desktop\Projects\Predicting Early Readmission for Diabetic Patients"
os.chdir(data_dir)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rahul\\OneDrive\\Desktop\\Projects\\Predicting Early Readmission for Diabetic Patients'

# %%
file_name       =    'Model_data_2025-03-05 09-32-53.csv'

# %%
df              =    pd.read_csv(file_name, encoding = 'Latin-1')
print(df.columns)
print("\n Rows {0} Columns {1}".format(df.shape[0], df.shape[1]))
print(df.info())
n               =   df.shape[0]
# Out:
# Index(['race', 'gender', 'age', 'admission_type_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'Discharged to',
#        'Target'],
#       dtype='object')
#
#  Rows 95431 Columns 45
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95431 entries, 0 to 95430
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   race                      95431 non-null  float64
#  1   gender                    95431 non-null  float64
#  2   age                       95431 non-null  float64
#  3   admission_type_id         95431 non-null  float64
#  4   admission_source_id       95431 non-null  float64
#  5   time_in_hospital          95431 non-null  float64
#  6   payer_code                95431 non-null  float64
#  7   medical_specialty         95431 non-null  float64
#  8   num_lab_procedures        95431 non-null  float64
#  9   num_procedures            95431 non-null  float64
#  10  num_medications           95431 non-null  float64
#  11  number_outpatient         95431 non-null  float64
#  12  number_emergency          95431 non-null  float64
#  13  number_inpatient          95431 non-null  float64
#  14  diag_1                    95431 non-null  float64
#  15  diag_2                    95431 non-null  float64
#  16  diag_3                    95431 non-null  float64
#  17  number_diagnoses          95431 non-null  float64
#  18  max_glu_serum             95431 non-null  float64
#  19  A1Cresult                 95431 non-null  float64
#  20  metformin                 95431 non-null  float64
#  21  repaglinide               95431 non-null  float64
#  22  nateglinide               95431 non-null  float64
#  23  chlorpropamide            95431 non-null  float64
#  24  glimepiride               95431 non-null  float64
#  25  acetohexamide             95431 non-null  float64
#  26  glipizide                 95431 non-null  float64
#  27  glyburide                 95431 non-null  float64
#  28  tolbutamide               95431 non-null  float64
#  29  pioglitazone              95431 non-null  float64
#  30  rosiglitazone             95431 non-null  float64
#  31  acarbose                  95431 non-null  float64
#  32  miglitol                  95431 non-null  float64
#  33  troglitazone              95431 non-null  float64
#  34  tolazamide                95431 non-null  float64
#  35  insulin                   95431 non-null  float64
#  36  glyburide-metformin       95431 non-null  float64
#  37  glipizide-metformin       95431 non-null  float64
#  38  glimepiride-pioglitazone  95431 non-null  float64
#  39  metformin-rosiglitazone   95431 non-null  float64
#  40  metformin-pioglitazone    95431 non-null  float64
#  41  change                    95431 non-null  float64
#  42  diabetesMed               95431 non-null  float64
#  43  Discharged to             95431 non-null  float64
#  44  Target                    95431 non-null  float64
# dtypes: float64(45)
# memory usage: 32.8 MB
# None

# %%
start_time = time.time()

# %%
### We shall use the 15 predictor variables selected by RFE method
Xcols            =   ['gender', 'age', 'admission_type_id', 'time_in_hospital', 'num_lab_procedures', 'num_medications', 'number_inpatient',\
                      'diag_1', 'diag_2', 'diag_3', 'metformin', 'insulin', 'change', 'diabetesMed', 'Discharged to']

target           =  'Target'
df['Target'].value_counts()
# Out:
# Target
# 0.0    84627
# 1.0    10804
# Name: count, dtype: int64

# %%
X               =    df.loc[:, Xcols]
y               =    df.loc[:, target]

# %% [markdown]
# ### Spot checking performance of various models using default parameters

# %%
spot_check_default_model_performance(n_splits = 10, random_state = 123456, df = df, X = X, y= y)
# Out:
#  n_splits 10 random_state 123456
#
# Measure:  recall Mean ± std.deviation, min, max
# LR: 0.020000 ± 0.000000 0.010000 0.020000
# KNN: 0.020000 ± 0.000000 0.010000 0.030000
# CART: 0.190000 ± 0.010000 0.170000 0.200000
# NB: 0.110000 ± 0.010000 0.100000 0.120000
# RF: 0.010000 ± 0.000000 0.010000 0.020000
# XGBoost: 0.020000 ± 0.000000 0.020000 0.040000
# AdaBoost: 0.010000 ± 0.000000 0.010000 0.020000
# Measure:  roc_auc Mean ± std.deviation, min, max
# LR: 0.640000 ± 0.010000 0.630000 0.650000
# KNN: 0.520000 ± 0.010000 0.510000 0.540000
# CART: 0.530000 ± 0.010000 0.520000 0.540000
# NB: 0.640000 ± 0.000000 0.630000 0.640000
# RF: 0.640000 ± 0.010000 0.630000 0.650000
# XGBoost: 0.650000 ± 0.010000 0.640000 0.660000
# AdaBoost: 0.660000 ± 0.010000 0.650000 0.670000
# Execution time for comparison of models using default parameters:   Hours:  0.0  Min:  8.0 Seconds:  34.66277194023132

# %% [markdown]
# ### Spot checking performance of various models using tuned parameters

# %%
spot_check_model_performance(n_splits = 10, random_state = 123456, df = df, X = X, y= y)
# Out:
# n_splits 10 random_state 123456
#
# Measure:  recall Mean ± std.deviation, min, max
# LR: 0.020000 ± 0.000000 0.010000 0.020000
# KNN: 0.050000 ± 0.010000 0.040000 0.070000
# CART: 0.550000 ± 0.060000 0.510000 0.660000
# NB: 0.110000 ± 0.010000 0.100000 0.120000
# RF: 0.630000 ± 0.010000 0.600000 0.640000
# XGBoost: 0.040000 ± 0.000000 0.030000 0.040000
# AdaBoost: 0.000000 ± 0.000000 0.000000 0.010000
# Measure:  roc_auc Mean ± std.deviation, min, max
# LR: 0.580000 ± 0.010000 0.570000 0.600000
# KNN: 0.520000 ± 0.010000 0.510000 0.530000
# CART: 0.620000 ± 0.000000 0.610000 0.630000
# NB: 0.640000 ± 0.000000 0.630000 0.640000
# RF: 0.660000 ± 0.010000 0.650000 0.670000
# XGBoost: 0.610000 ± 0.010000 0.600000 0.620000
# AdaBoost: 0.650000 ± 0.000000 0.640000 0.660000
# Execution time for comparison of models using tuned parameters:   Hours:  0.0  Min:  3.0 Seconds:  23.62880778312683

# %%
end_time         = time.time()
time_taken       = end_time - start_time # time_taken is in seconds
hours, rest      = divmod(time_taken,3600)
minutes, seconds = divmod(rest, 60)
print("\nExecution time: ", " Hours: ", hours, " Min: ", minutes, "Seconds: ", seconds)
# Out:
# Execution time:   Hours:  0.0  Min:  12.0 Seconds:  5.10025954246521

# %% [markdown]
# ### Observations
#
# Using the tuned parameters after hyper parameter tuning, we have obtained the following measures for model performance.
#
# **Recall** Recall is a metric that measures how often a machine learning model correctly identifies positive instances (true positives) from all the actual positive samples in the dataset.
# Recall after 10-Fold cross validation, mean and std.deviation for the measure, **recall for the minority dataset** are given below for the best models:
#
# 0.55 ± 0.06, the minimum being 0.51 and maximum being 0.66 for **Decision Tree Model**
#
# 0.62 ± 0.01, the minimum being 0.60 and maximum being 0.65 for **Random Forest Model**
#
# **AUROC** ROC is a probability curve and AUC represents the degree or measure of separability. It tells how much the model is capable of distinguishing between classes. AUROC is given for the above models.
#
# **Decision Tree (CART)**: 0.62 ± 0.00 Minimum: 0.61 Maximum: 0.63
#
# **Random Forest (RF)**:   0.66 ± 0.01 Minimum: 0.65 Maximum: 0.67

# %%
from    sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, train_size = 0.8, test_size = 0.2, random_state =3, stratify = y)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (76344, 15) (19087, 15) (76344,) (19087,)

# %%
from    sklearn.tree                import   DecisionTreeClassifier

# %% [markdown]
# ### 1) Using the raw data

# %%
clf                    =   RandomForestClassifier(warm_start = False, verbose = 0, random_state = None, oob_score = False, n_jobs = None, n_estimators= 50,\
                            min_weight_fraction_leaf = 0.0, min_samples_split = 2, min_samples_leaf =  1, min_impurity_decrease = 0.0,\
                            max_samples = None, max_leaf_nodes = None, max_features = 0.75, max_depth = 5, criterion = 'gini',\
                            class_weight = 'balanced', ccp_alpha = 0.0, bootstrap = True)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, max_features=0.75,
#                        n_estimators=50)

# %%
report_performance(clf, X_train, X_test, y_train, y_test)
# Out:
# Using Training data
#
# precision score: 0.17
# recall score: 0.62
# f1 score: 0.27
#
# Using Test data
#
# precision score: 0.17
# recall score: 0.61
# f1 score: 0.27
#                Columns  % Reduction in a criterion
# 6     number_inpatient                   59.261824
# 14       Discharged to                   22.729326
# 7               diag_1                    4.636901
# 1                  age                    3.498949
# 5      num_medications                    2.024712
# 8               diag_2                    1.650716
# 3     time_in_hospital                    1.285844
# 4   num_lab_procedures                    1.216514
# 9               diag_3                    1.083230
# 13         diabetesMed                    1.053851
# 11             insulin                    0.592323
# 2    admission_type_id                    0.577109
# 10           metformin                    0.280426
# 12              change                    0.086168
# 0               gender                    0.022106

# %% [markdown]
# ### 2) Using the data after applying SMOTE

# %% [markdown]
# ###  Apply SMOTE techniques
# #### Evaluating model performance using the data after applying SMOTE

# %%
from    imblearn.over_sampling   import SMOTE
    
# transform the dataset
oversample                    =  SMOTE()
    
X_train_SMOTE, y_train_SMOTE  =  oversample.fit_resample(X_train, y_train)

# %%
report_performance(clf, X_train_SMOTE, X_test, y_train_SMOTE, y_test)
# Out:
# Using Training data
#
# precision score: 0.63
# recall score: 0.65
# f1 score: 0.64
#
# Using Test data
#
# precision score: 0.17
# recall score: 0.61
# f1 score: 0.27
#                Columns  % Reduction in a criterion
# 6     number_inpatient                   59.261824
# 14       Discharged to                   22.729326
# 7               diag_1                    4.636901
# 1                  age                    3.498949
# 5      num_medications                    2.024712
# 8               diag_2                    1.650716
# 3     time_in_hospital                    1.285844
# 4   num_lab_procedures                    1.216514
# 9               diag_3                    1.083230
# 13         diabetesMed                    1.053851
# 11             insulin                    0.592323
# 2    admission_type_id                    0.577109
# 10           metformin                    0.280426
# 12              change                    0.086168
# 0               gender                    0.022106

# %% [markdown]
# ### 3) Using the data after applying Random under-sampling
#
#
# RandomUnderSampler is a fast and easy way to balance the data by randomly selecting a subset of data for the targeted classes.

# %%
from    imblearn.under_sampling     import   RandomUnderSampler

# %%
under_sampling             =    RandomUnderSampler(random_state = 0)
X_under, y_under           =   under_sampling.fit_resample(X, y)

# %%
report_performance(clf, X_under, X_test, y_under, y_test)
# Out:
# Using Training data
#
# precision score: 0.62
# recall score: 0.62
# f1 score: 0.62
#
# Using Test data
#
# precision score: 0.17
# recall score: 0.61
# f1 score: 0.27
#                Columns  % Reduction in a criterion
# 6     number_inpatient                   59.261824
# 14       Discharged to                   22.729326
# 7               diag_1                    4.636901
# 1                  age                    3.498949
# 5      num_medications                    2.024712
# 8               diag_2                    1.650716
# 3     time_in_hospital                    1.285844
# 4   num_lab_procedures                    1.216514
# 9               diag_3                    1.083230
# 13         diabetesMed                    1.053851
# 11             insulin                    0.592323
# 2    admission_type_id                    0.577109
# 10           metformin                    0.280426
# 12              change                    0.086168
# 0               gender                    0.022106

# %% [markdown]
# ### 4) Using the data after applying SMOTEENN

# %%
from    imblearn.combine        import  SMOTEENN

# %%
'''
Over-sampling using SMOTE and cleaning using ENN.    
Combine over- and under-sampling using SMOTE and Edited Nearest Neighbours.
Ref: https://imbalanced-learn.org/stable/combine.html#combine
'''
sme = SMOTEENN(random_state=42)
X_res, y_res = sme.fit_resample(X_train, y_train)

# %%
report_performance(clf, X_res, X_test, y_res, y_test)
# Out:
# Using Training data
#
# precision score: 0.75
# recall score: 0.66
# f1 score: 0.70
#
# Using Test data
#
# precision score: 0.17
# recall score: 0.61
# f1 score: 0.27
#                Columns  % Reduction in a criterion
# 6     number_inpatient                   59.261824
# 14       Discharged to                   22.729326
# 7               diag_1                    4.636901
# 1                  age                    3.498949
# 5      num_medications                    2.024712
# 8               diag_2                    1.650716
# 3     time_in_hospital                    1.285844
# 4   num_lab_procedures                    1.216514
# 9               diag_3                    1.083230
# 13         diabetesMed                    1.053851
# 11             insulin                    0.592323
# 2    admission_type_id                    0.577109
# 10           metformin                    0.280426
# 12              change                    0.086168
# 0               gender                    0.022106

# %% [markdown]
# ### For training data

# %%
mname             =    'Random Forest'
datacategory      =    'Training dataset'
y_pred            =    clf.predict(X_train)

# %%
draw_cm(mname, datacategory, y_train, y_pred )
draw_roc(mname, datacategory, y_train, y_pred )
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.62      0.74     67701
#          1.0       0.17      0.62      0.27      8643
#
#     accuracy                           0.62     76344
#    macro avg       0.55      0.62      0.51     76344
# weighted avg       0.84      0.62      0.69     76344
# (array([0.        , 0.37935924, 1.        ]),
#  array([0.        , 0.62408886, 1.        ]),
#  array([inf,  1.,  0.]))

# %% [markdown]
# ### For test data

# %%
mname             =    'Random Forest'
datacategory      =    'Test dataset'
y_pred            =    clf.predict(X_test)

# %%
draw_cm(mname, datacategory, y_test, y_pred )
draw_roc(mname, datacategory, y_test, y_pred )
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.62      0.74     16926
#          1.0       0.17      0.61      0.27      2161
#
#     accuracy                           0.62     19087
#    macro avg       0.55      0.62      0.51     19087
# weighted avg       0.84      0.62      0.69     19087
# (array([0.       , 0.3775257, 1.       ]),
#  array([0.        , 0.61129107, 1.        ]),
#  array([inf,  1.,  0.]))

# %%
#Create a pickle of fitted model
with open('final_model.pkl','wb')as file:
    pickle.dump(clf,file)
